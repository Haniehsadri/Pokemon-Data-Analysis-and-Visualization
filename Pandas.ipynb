# %%
import pandas as pd

df=pd.read_csv('pokemon_data.csv')
print (df)
df.describe()
df.sort_values('Name' ,ascending=1)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print (df.head(5))
print (df.columns)
print(df['Name'][0:5])
print (df.Name)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# ...

# %%
# # #print (df[['Name','HP']])
import re
# # #print(df.iloc[1:4])
# # for a,r in df.iterrows():
# #     print (a,r)
#df.loc[df['Type 1']=='Fire']
#df
df['Total'] = df.iloc[:, 4:9].sum(axis=1)
#df.head(5)
#new_ df=df.loc[(df['Type 1']=='Grass')&(df['Tye 2']=='Poison')]
#new _df
#new_df.reset_index(drop=True,inplace=True)
# new_df2=df.loc[df['Name'].str.contains("Mega")]
#df.loc[df['Type 1'].str.contains('grass|fire' ,flags=re.I, regex=True)]
df.loc[df['Type 1']=='Fire','Type 1']='Flame'
df
# Out:
# <ipython-input-22-1a4c129e7fc3>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total'] = df.iloc[:, 4:9].sum(axis=1)
# c:\users\hanieh\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        #                   Name   Type 1  Type 2  Legendary.1  Legendary  HP  \
# 0      1              Bulbasaur    Grass  Poison        False      False  45
# ...

# %%
# for index,row in df.iterrows():
#     print(index,row['Name'])
cols=list(df.columns)
df=df[cols[0:4]+[cols[-1]]+cols[4:12]]
print(df.head(4))
df.to_csv('modified.csv')
df.to_csv('modified1.csv',index=False)
# Out:
#    #                   Name Type 1  Type 2  Total  Legendary.1  Legendary  HP  \
# 0  1              Bulbasaur  Grass  Poison  143.0        False      False  45
# 1  2                Ivysaur  Grass  Poison  185.0        False      False  60
# 2  3               Venusaur  Grass  Poison  245.0        False      False  80
# 3  3  VenusaurMega Venusaur  Grass  Poison  303.0        False      False  80
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      49       49       65       65     45
# 1      62       63       80       80     60
# 2      82       83      100      100     80
# 3     100      123      122      120     80

# %%
df.loc[df['Total']>500 , ['Generation','Legendary']]='TEST VALUE'

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander    Flame     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion    Flame   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation   Legendary  Total
# 0         65       65     45           1       False    273
# ...

# %%
df=pd.read_csv('modified.csv')
df.groupby(['Type 1']).mean()
df.groupby(['Type 1']).mean().sort_values('Defense',ascending=False)
df.groupby(['Type 1']).count()
df['count']=1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Flame        52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
for df in pd.read_csv('modified.csv',chunksize=5):
    print("chunk df")
    print(df)
# Out:
# chunk df
#    Unnamed: 0  #                   Name Type 1  Type 2  Total  Legendary.1  \
# 0           0  1              Bulbasaur  Grass  Poison  143.0        False
# 1           1  2                Ivysaur  Grass  Poison  185.0        False
# 2           2  3               Venusaur  Grass  Poison  245.0        False
# 3           3  3  VenusaurMega Venusaur  Grass  Poison  303.0        False
# 4           4  4             Charmander  Flame     NaN  134.0        False
#
#    Legendary  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0      False  45      49       49       65       65     45
# 1      False  60      62       63       80       80     60
# 2      False  80      82       83      100      100     80
# 3      False  80     100      123      122      120     80
# 4      False  39      52       43       60       50     65
# chunk df
#    Unnamed: 0  #                       Name Type 1  Type 2  Total  \
# 5           5  5                 Charmeleon  Flame     NaN  180.0
# ...
